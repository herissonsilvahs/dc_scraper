# %%
import pandas as pd
from decimal import Decimal
from re import sub

# %%
df_csv_2017 = pd.read_csv('data/empenho_2017.csv')
df_csv_2018 = pd.read_csv('data/empenho_2018.csv')
df_csv_2019 = pd.read_csv('data/empenho_2019.csv')

df_csv = pd.concat([df_csv_2017, df_csv_2018, df_csv_2019])

# %%
df_csv.info() # Informações dos campos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17638 entries, 0 to 3693
# Data columns (total 8 columns):
# Data                       17638 non-null object
# Empenho                    17638 non-null int64
# Unidade gestora            17638 non-null object
# CPF/CNPJ                   16773 non-null object
# Natureza da despesa        17638 non-null object
# Modalidade da licitação    17638 non-null object
# Registro                   17638 non-null object
# Valor (R$)                 17638 non-null object
# dtypes: int64(1), object(7)
# memory usage: 1.2+ MB

# %%
df_csv[df_csv['CPF/CNPJ'].isna()==True]
# Out:
#             Data  Empenho                                    Unidade gestora  \
# 224   01/03/2017  2010436                004 - Secretaria Municipal de Saúde
# 225   01/03/2017  1030001        006 - Sec. Mun. Assist. Social. e Cidadania
# 226   01/03/2017  1030015              009 - Procuradoria Geral do Municipio
# 227   01/03/2017  1030008        006 - Sec. Mun. Assist. Social. e Cidadania
# 254   02/03/2017  2030033               039 - Secretaria Municipal da Cidade
# 255   02/03/2017  2030013                004 - Secretaria Municipal de Saúde
# 719   03/04/2017  3040027     014 - Secretaria Mun. Seg. Publica e Cidadania
# 720   03/04/2017  2010072                004 - Secretaria Municipal de Saúde
# 721   03/04/2017  3040015        021 - Demutran - Dpto Municipal de Transito
# 722   03/04/2017  3040048              009 - Procuradoria Geral do Municipio
# 723   03/04/2017  3040033  046 - Secretaria Municipal de Desenvolvimento ...
# 724   03/04/2017  3040025  045 - Secretaria Extraordinária de Turismo e R...
# 725   03/04/2017  3040030               039 - Secretaria Municipal da Cidade
# 726   03/04/2017  3040039               037 - Secretaria Municipal de Gestao
# 727   03/04/2017  3040026        006 - Sec. Mun. Assist. Social. e Cidadania
# 728   03/04/2017  3040028                         008 - Gabinete do Prefeito
# 729   03/04/2017  3040012  047 - Secretaria Municipal Esporte, Juventude ...
# 730   03/04/2017  3040018  013 - Secretaria de Meio-Ambiente e Serv. Publ...
# 731   03/04/2017  3040013                 012 - Secretaria de Infraestrutura
# 732   03/04/2017  3040017  013 - Secretaria de Meio-Ambiente e Serv. Publ...
# 733   03/04/2017  3040053                004 - Secretaria Municipal de Saúde
# 1168  02/05/2017  2050037     014 - Secretaria Mun. Seg. Publica e Cidadania
# 1169  02/05/2017  2050023        006 - Sec. Mun. Assist. Social. e Cidadania
# 1170  02/05/2017  2050022        006 - Sec. Mun. Assist. Social. e Cidadania
# 1171  02/05/2017  2050026        006 - Sec. Mun. Assist. Social. e Cidadania
# 1172  02/05/2017  2050036                004 - Secretaria Municipal de Saúde
# 1173  02/05/2017  2050072                004 - Secretaria Municipal de Saúde
# 1174  02/05/2017  2050069                004 - Secretaria Municipal de Saúde
# 1175  02/05/2017  2050029        006 - Sec. Mun. Assist. Social. e Cidadania
# 1839  01/06/2017  1060060               037 - Secretaria Municipal de Gestao
# ...          ...      ...                                                ...
# 2129  03/06/2019  3060067       053 - Sec.Mun.Desenv.Soc.e Trabalho - SEDEST
# 2130  03/06/2019  3060047       053 - Sec.Mun.Desenv.Soc.e Trabalho - SEDEST
#
# 722     Outros/não se aplica  Realizado     35.000,00
# 723     Outros/não se aplica  Realizado     60.000,00
# 724     Outros/não se aplica  Realizado     85.000,00
# 725     Outros/não se aplica  Realizado    120.000,00
# 726     Outros/não se aplica  Realizado    150.000,00
# 727     Outros/não se aplica  Realizado    200.000,00
# 728     Outros/não se aplica  Realizado    245.000,00
# 729     Outros/não se aplica  Realizado    350.000,00
# 730     Outros/não se aplica  Realizado    360.000,00
# 731     Outros/não se aplica  Realizado    500.000,00
# 732     Outros/não se aplica  Realizado  1.000.000,00
# 733     Outros/não se aplica  Realizado  2.000.000,00
# 1168    Outros/não se aplica  Realizado     20.000,00
# 1169    Outros/não se aplica  Realizado     30.000,00
# 1170    Outros/não se aplica  Realizado     80.000,00
# 1171    Outros/não se aplica  Realizado    100.000,00
# 1172    Outros/não se aplica  Realizado    200.000,00
# 1173    Outros/não se aplica  Realizado    500.000,00
# 1174    Outros/não se aplica  Realizado    600.000,00
# 1175    Outros/não se aplica  Realizado  2.000.000,00
# 1839    Outros/não se aplica  Realizado     17.631,75
# ...                      ...        ...           ...
# 2129    Outros/não se aplica  Realizado    500.000,00
# 2130    Outros/não se aplica  Realizado     40.000,00
# 2131    Outros/não se aplica  Realizado    350.000,00
# 2132    Outros/não se aplica  Realizado  1.300.000,00
# 2782    Outros/não se aplica  Realizado     18.000,00
# 2783    Outros/não se aplica  Realizado     64.000,00
# 2784    Outros/não se aplica  Realizado    100.000,00
# 2785    Outros/não se aplica  Realizado    155.000,00
# 2786    Outros/não se aplica  Realizado    168.000,00
# 2787    Outros/não se aplica  Realizado    300.000,00
# 2788    Outros/não se aplica  Realizado    300.000,00
# 2789    Outros/não se aplica  Realizado    400.000,00
# 2790    Outros/não se aplica  Realizado    560.000,00
# 2791    Outros/não se aplica  Realizado    730.000,00
# 2792    Outros/não se aplica  Realizado  1.100.000,00
# 2793    Outros/não se aplica  Realizado  1.800.000,00
# 2794    Outros/não se aplica    Anulado  8.412.850,84
# 2795    Outros/não se aplica  Realizado     80.000,00
# 2796    Outros/não se aplica  Realizado    200.000,00
# 2797    Outros/não se aplica  Realizado    213.000,00
# 2798    Outros/não se aplica  Realizado     30.000,00
# 3368    Outros/não se aplica  Realizado     20.000,00
# 3369    Outros/não se aplica  Realizado     20.000,00
# 3370    Outros/não se aplica  Realizado    126.500,00
# 3371    Outros/não se aplica  Realizado    130.000,00
# 3372    Outros/não se aplica  Realizado    150.000,00
# 3373    Outros/não se aplica  Realizado    160.000,00
# 3374    Outros/não se aplica  Realizado  1.000.000,00
# 3375    Outros/não se aplica  Realizado  3.000.000,00
# 3376    Outros/não se aplica  Realizado     13.000,00
#
# [865 rows x 8 columns]

# %%
def to_float(x):
    x = sub(r'[.]', '', x)
    x = sub(r'[,]', '.', x)
    return float(x)

# %%
df_csv['Valor (R$)'] = df_csv['Valor (R$)'].apply(to_float)

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3232 entries, 0 to 3231
# Data columns (total 8 columns):
# Data                       3232 non-null object
# Empenho                    3232 non-null int64
# Unidade gestora            3232 non-null object
# CPF/CNPJ                   3049 non-null object
# Natureza da despesa        3232 non-null object
# Modalidade da licitação    3232 non-null object
# Registro                   3232 non-null object
# Valor (R$)                 3232 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 202.1+ KB

# %%
df_csv['Valor (R$)'].min()
# Out:
# 2.95

# %%
df_csv['Valor (R$)'].max()
# Out:
# 10400000.0

# %%
df_csv['Valor (R$)'].mean()
# Out:
# 67560.63483601485

# %%
df_csv[df_csv['Valor (R$)'] == df_csv['Valor (R$)'].min()]
# Out:
#            Data   Empenho                               Unidade gestora  \
# 832  20/03/2018  20030021  053 - Sec.Mun.Desenv.Soc.e Trabalho - SEDEST
#
#                 CPF/CNPJ                                Natureza da despesa  \
# 832  XX.X00.000/ 0433-20  3.3.90.39.00 - Outros serv. de terc. pessoa ju...
#
#     Modalidade da licitação   Registro  Valor (R$)
# 832    Outros/não se aplica  Realizado        2.95

# %%
df_csv[df_csv['Valor (R$)'] == df_csv['Valor (R$)'].max()]
# Out:
#             Data  Empenho                         Unidade gestora CPF/CNPJ  \
# 1675  02/05/2018  2050075  005 - Secretaria Municipal de Educação      NaN
#
#                                     Natureza da despesa  \
# 1675  3.1.90.11.00 - Vencimentos e vant. fixas pesso...
#
#      Modalidade da licitação   Registro  Valor (R$)
# 1675    Outros/não se aplica  Realizado  10400000.0

# %%
df_csv['Unidade gestora'].unique()
# Out:
# array(['004 - Secretaria Municipal de Saúde',
#        '005 - Secretaria Municipal de Educação',
#        '050 - Secretaria Municipal de Cultura',
#        '014 - Secretaria Mun. Seg. Publica e Cidadania',
#        '012 - Secretaria de Infraestrutura',
#        '043 - Autarquia Municipal do Meio Ambiente',
#        '046 - Secretaria Municipal de Desenvolvimento Econômico',
#        '052 - Sec. Mun. de Esporte e Juventude',
#        '013 - Secretaria de Meio-Ambiente e Serv. Publicos',
#        '021 - Demutran - Dpto Municipal de Transito',
#        '049 - Sec. Mun. de Administração e Finanças',
#        '051 - Sec. Mun. de Agricultura e Abastecimento',
#        '053 - Sec.Mun.Desenv.Soc.e Trabalho - SEDEST',
#        '008 - Gabinete do Prefeito',
#        '009 - Procuradoria Geral do Municipio',
#        '054 - Secretaria Municipal de Turismo e Romaria',
#        '042 - Controladoria e Ouvidoria Geral do Municipio',
#        '055 - Guarda Civil Municipal - GCM',
#        '022 - Fundacao Memorial Padre Cicero',
#        '056 - Fundo M.dos Dir.da Criança e Adolescente'], dtype=object)

# %%
df_csv[df_csv['Unidade gestora'] == '012 - Secretaria de Infraestrutura'].max()
# Out:
# Data                                                              30/05/2018
# Empenho                                                             30050052
# Unidade gestora                           012 - Secretaria de Infraestrutura
# Natureza da despesa        4.4.90.52.00 - Equipamentos e material permanente
# Modalidade da licitação                                      Tomada de preço
# Registro                                                           Realizado
# Valor (R$)                                                             3e+06
# dtype: object

# %%
df_csv[df_csv['Unidade gestora'] == '049 - Sec. Mun. de Administração e Finanças'].max()
# Out:
# Data                                                              29/06/2018
# Empenho                                                             29060009
# Unidade gestora                  049 - Sec. Mun. de Administração e Finanças
# Natureza da despesa        4.6.90.71.00 - Principal da dívida contratual ...
# Modalidade da licitação                                      Tomada de preço
# Registro                                                           Realizado
# Valor (R$)                                                             2e+06
# dtype: object

# %%
from collections import Counter

# %%
Counter(df_csv['Empenho'] > 1)
# Out:
# Counter({True: 3232})
